# %%
import matplotlib.pyplot as plt

# %%
#new file
#no and with smearing
#with cuts
#unified
#2 sigma window
#first two strategy


perc_list = [80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]

#no smearing
eff_list_nosm = [0.76375,0.77625,0.78375,0.79375,0.8025,0.80875, 0.815,0.81875,0.8325,0.83875,0.85375,0.85625, 0.86375, 0.86875,0.87125,0.87125,0.87125,0.87375,0.875,0.875]
ghostr_list_nosm = [0.239103362391,0.238036809816,0.23815309842,0.237695078031,0.237529691211,0.237028301887,0.236533957845,0.236596736597,0.23623853211,0.2375,0.236017897092,0.23719376392,0.236464088398,0.237938596491,0.23825136612,0.237991266376,0.237991266376,0.237731733915,0.237472766885,0.237472766885]

#with smearing
eff_list_wsm = [0.765, 0.77375, 0.78125, 0.79625, 0.80375, 0.81625, 0.8225, 0.8275, 0.8375, 0.84375, 0.85125, 0.85875, 0.8625, 0.865, 0.865, 0.86625, 0.86875, 0.8675, 0.86625, 0.86375]
ghostr_list_wsm = [0.245376078915,0.248786407767,0.246079613993,0.243467933492,0.243529411765,0.244212962963,0.247139588101,0.246871444824,0.244644870349,0.243273542601,0.247513812155,0.245883644347,0.24672489083,0.250270855905,0.252699784017,0.252427184466,0.249460043197,0.251348435814,0.249187432286,0.252972972973]


fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13,5))
fig.suptitle('First two strategy: long and downstream tracks with UT')
axs[0].scatter(perc_list,eff_list_nosm,label='without smearing')
axs[0].scatter(perc_list,eff_list_wsm,label='with smearing')
axs[0].set_xlabel('chi2 percentage threshold')
axs[0].set_ylabel('real matches/long and downstream tracks')
axs[0].legend(loc='best')
axs[0].set_title('Efficiency')


axs[1].scatter(perc_list,ghostr_list_nosm,label='without smearing')
axs[1].scatter(perc_list,ghostr_list_wsm,label='with smearing')
axs[1].set_xlabel('chi2 percentage threshold')
axs[1].set_ylabel('wrong matches/found matches')
axs[1].legend(loc='best')
axs[1].set_title('Ghost rate')
plt.show()

# %%
perc_list_UT = range(99,79,-1)
perc_list_noUT = range(99,89,-1)

#no smearing UT
eff_list_nosm_UT = [0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.92, 0.92, 0.92, 0.915, 0.915, 0.915, 0.91, 0.905]
ghostr_list_nosm_UT = [0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.264, 0.264, 0.264, 0.26506024096385544, 0.26506024096385544, 0.26506024096385544, 0.2661290322580645, 0.26720647773279355]
#with smearing UT
eff_list_wsm_UT = [0.925, 0.93, 0.925, 0.93, 0.93, 0.92, 0.92, 0.925, 0.93, 0.93, 0.925, 0.92, 0.92, 0.915, 0.92, 0.92, 0.915, 0.915, 0.91, 0.905]
ghostr_list_wsm_UT = [0.26294820717131473, 0.2589641434262948, 0.26294820717131473, 0.2589641434262948, 0.2589641434262948, 0.26693227091633465, 0.26693227091633465, 0.26294820717131473, 0.2589641434262948, 0.2589641434262948, 0.26294820717131473, 0.264, 0.264, 0.268, 0.264, 0.26104417670682734, 0.26506024096385544, 0.26506024096385544, 0.2661290322580645, 0.26720647773279355]

#no smearing no UT
eff_list_wsm_noUT = [0.89, 0.895, 0.885, 0.89, 0.89, 0.885, 0.89, 0.885, 0.89, 0.895]
ghostr_list_wsm_noUT = [0.25523012552301255, 0.2510460251046025, 0.2594142259414226, 0.25523012552301255, 0.25523012552301255, 0.2594142259414226, 0.25523012552301255, 0.2594142259414226, 0.25523012552301255, 0.2510460251046025]
#no smearing no UT
eff_list_nosm_noUT = [0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89]
ghostr_list_nosm_noUT = [0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336]

# %%
#new file
#no and with smearing
#with cuts
#unified
#first last strategy
#long and downstream tracks
#2 sigma window

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13,5))
fig.suptitle('Long and downstream tracks with UT')
axs[0].scatter(perc_list_UT,eff_list_nosm_UT,label='without smearing')
axs[0].scatter(perc_list_UT,eff_list_wsm_UT,label='with smearing')
axs[0].set_xlabel('chi2 percentage threshold')
axs[0].set_ylabel('real matches/long and downstream tracks')
axs[0].legend(loc='best')
axs[0].set_title('Efficiency')


axs[1].scatter(perc_list_UT,ghostr_list_nosm_UT,label='without smearing')
axs[1].scatter(perc_list_UT,ghostr_list_wsm_UT,label='with smearing')
axs[1].set_xlabel('chi2 percentage threshold')
axs[1].set_ylabel('wrong matches/found matches')
axs[1].legend(loc='best')
axs[1].set_title('Ghost rate')
plt.show()

# %%
#new file
#no and with smearing
#with cuts
#unified
#first last strategy
#only long tracks (velovelo, not downstream, no UT)
#2 sigma window also 1 sigma

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13,5))
fig.suptitle('Long tracks with no UT')

axs[0].scatter(perc_list_noUT,eff_list_nosm_noUT,label='without smearing')
axs[0].scatter(perc_list_noUT,eff_list_wsm_noUT,label='with smearing')
axs[0].set_xlabel('chi2 percentage threshold')
axs[0].set_ylabel('real matches/long tracks')
axs[0].legend(loc='best')
axs[0].set_title('Efficiency')


axs[1].scatter(perc_list_noUT,ghostr_list_nosm_noUT,label='without smearing')
axs[1].scatter(perc_list_noUT,ghostr_list_wsm_noUT,label='with smearing')
axs[1].set_xlabel('chi2 percentage threshold')
axs[1].set_ylabel('wrong matches/found matches')
axs[1].legend(loc='best')
axs[1].set_title('Ghost rate')
plt.show()

# %%
#new file
#with smearing
#no cuts
#unified
#only long tracks
#perc 93%

#first two strategy

#2 sigma window
efficiency = 0.84
ghostrate = 0.345029239766
real chi2 below threshold / chi2 below threshold  = 0.200681237582
#1 sigma window
efficiency =  0.75125
ghostrate = 0.356531049251
real chi2 below threshold / chi2 below threshold = 0.358294930876
# -> decided 2sigma


#first last strategy 2 sigma window (13h)
