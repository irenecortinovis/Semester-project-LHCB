# %%
import matplotlib.pyplot as plt

# %%
#new file, no smearing, with cuts, VeloVelo: efficiencies and ghostrate, 800 events per %

perc_list = [80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
eff_list = [0.513916500994, 0.528827037773, 0.531809145129,0.543737574553,0.55268389662,0.563618290258,0.575546719682,0.58648111332,0.596421471173,0.609343936382,0.62027833002,0.630218687873,0.643141153082,0.649105367793,0.659045725646,0.663021868787,0.668986083499,0.669980119284,0.669980119284,0.669980119284]
ghostr_list = [0.204771371769,0.211729622266,0.214711729622,0.219681908549,0.224652087475,0.231610337972,0.235586481113,0.235586481113,0.237574552684,0.24055666004,0.24254473161,0.243538767396,0.245526838966,0.252485089463,0.252485089463,0.254473161034,0.256461232604,0.256461232604,0.256461232604,0.256461232604]

# %%
plt.scatter(perc_list,eff_list)
plt.show()
plt.scatter(perc_list,ghostr_list)
plt.show()

# %%
#new file, no smearing, with cuts, veloUT: efficiencies and ghostrate, 800 events per %

perc_list = [90,92,93,94,95,96,97,98,99]
eff_list = [0.686534216336,0.711920529801,0.718543046358,0.729580573951,0.733995584989, 0.741721854305,0.742825607064, 0.742825607064, 0.742825607064]
ghostr_list = [0.0993377483444,0.108167770419,0.115894039735,0.12582781457, 0.131346578366, 0.136865342163, 0.136865342163, 0.136865342163, 0.136865342163]

# %%
plt.scatter(perc_list,eff_list)
plt.show()
plt.scatter(perc_list,ghostr_list)
plt.show()

# %%
#new file, no smearing, with cuts, UTUT: efficiencies and ghostrate, 800 events per %

# %%
#new file
#no and with smearing
#with cuts
#unified
#2 sigma window
#first two strategy


perc_list = [80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]

#no smearing
eff_list_nosm = [0.76375,0.77625,0.78375,0.79375,0.8025,0.80875, 0.815,0.81875,0.8325,0.83875,0.85375,0.85625, 0.86375, 0.86875,0.87125,0.87125,0.87125,0.87375,0.875,0.875]
ghostr_list_nosm = [0.239103362391,0.238036809816,0.23815309842,0.237695078031,0.237529691211,0.237028301887,0.236533957845,0.236596736597,0.23623853211,0.2375,0.236017897092,0.23719376392,0.236464088398,0.237938596491,0.23825136612,0.237991266376,0.237991266376,0.237731733915,0.237472766885,0.237472766885]

#with smearing
eff_list_wsm = [0.765, 0.77375, 0.78125, 0.79625, 0.80375, 0.81625, 0.8225, 0.8275, 0.8375, 0.84375, 0.85125, 0.85875, 0.8625, 0.865, 0.865, 0.86625, 0.86875, 0.8675, 0.86625, 0.86375]
ghostr_list_wsm = [0.245376078915,0.248786407767,0.246079613993,0.243467933492,0.243529411765,0.244212962963,0.247139588101,0.246871444824,0.244644870349,0.243273542601,0.247513812155,0.245883644347,0.24672489083,0.250270855905,0.252699784017,0.252427184466,0.249460043197,0.251348435814,0.249187432286,0.252972972973]


plt.scatter(perc_list,eff_list_nosm,label='without smearing')
plt.scatter(perc_list,eff_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('real matches/long tracks')
plt.legend(loc='best')
plt.title('Efficiency')
plt.show()

plt.scatter(perc_list,ghostr_list_nosm,label='without smearing')
plt.scatter(perc_list,ghostr_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('wrong matches/found matches')
plt.legend(loc='best')
plt.title('Ghost rate')
plt.show()

# %%
#new file
#no and with smearing
#with cuts
#unified
#first last strategy
#long and downstream tracks
#2 sigma window

perc_list = range(99,79,-1)

#no smearing
eff_list_nosm = [0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.92, 0.92, 0.92, 0.915, 0.915, 0.915, 0.91, 0.905]
ghostr_list_nosm = [0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.26294820717131473, 0.264, 0.264, 0.264, 0.26506024096385544, 0.26506024096385544, 0.26506024096385544, 0.2661290322580645, 0.26720647773279355]


#with smearing
eff_list_wsm = [0.925, 0.93, 0.925, 0.93, 0.93, 0.92, 0.92, 0.925, 0.93, 0.93, 0.925, 0.92, 0.92, 0.915, 0.92, 0.92, 0.915, 0.915, 0.91, 0.905]
ghostr_list_wsm = [0.26294820717131473, 0.2589641434262948, 0.26294820717131473, 0.2589641434262948, 0.2589641434262948, 0.26693227091633465, 0.26693227091633465, 0.26294820717131473, 0.2589641434262948, 0.2589641434262948, 0.26294820717131473, 0.264, 0.264, 0.268, 0.264, 0.26104417670682734, 0.26506024096385544, 0.26506024096385544, 0.2661290322580645, 0.26720647773279355]


plt.scatter(perc_list,eff_list_nosm,label='without smearing')
plt.scatter(perc_list,eff_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('real matches/long tracks')
plt.legend(loc='best')
plt.title('Efficiency')
plt.show()

plt.scatter(perc_list,ghostr_list_nosm,label='without smearing')
plt.scatter(perc_list,ghostr_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('wrong matches/found matches')
plt.legend(loc='best')
plt.title('Ghost rate')
plt.show()

# %%
#new file
#no and with smearing
#with cuts
#unified
#first last strategy
#only long tracks (velovelo, not downstream, no UT)
#2 sigma window also 1 sigma

perc_list = range(99,89,-1)
eff_list_wsm = [0.89, 0.895, 0.885, 0.89, 0.89, 0.885, 0.89, 0.885, 0.89, 0.895]
ghostr_list_wsm = [0.25523012552301255, 0.2510460251046025, 0.2594142259414226, 0.25523012552301255, 0.25523012552301255, 0.2594142259414226, 0.25523012552301255, 0.2594142259414226, 0.25523012552301255, 0.2510460251046025]
belowstats_list_wsm = [0.19560878243512975, 0.19541375872382852, 0.1952191235059761, 0.1952191235059761, 0.19541375872382852, 0.19502487562189055, 0.1952191235059761, 0.1952191235059761, 0.19502487562189055, 0.19502487562189055]


eff_list_nosm = [0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89, 0.89]
ghostr_list_nosm = [0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336, 0.25833333333333336]
belowstats_list_nosm = [0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18403755868544602, 0.18421052631578946, 0.18473138548539114]


plt.scatter(perc_list,eff_list_nosm,label='without smearing')
plt.scatter(perc_list,eff_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('real matches/long tracks')
plt.legend(loc='best')
plt.title('Efficiency')
plt.show()

plt.scatter(perc_list,ghostr_list_nosm,label='without smearing')
plt.scatter(perc_list,ghostr_list_wsm,label='with smearing')
plt.xlabel('chi2 percentage threshold')
plt.ylabel('wrong matches/found matches')
plt.legend(loc='best')
plt.title('Ghost rate')
plt.show()

# %%
#new file
#with smearing
#no cuts
#unified
#only long tracks
#perc 93%

#first two strategy

#2 sigma window
efficiency = 0.84
ghostrate = 0.345029239766
real chi2 below threshold / chi2 below threshold  = 0.200681237582
#1 sigma window
efficiency =  0.75125
ghostrate = 0.356531049251
real chi2 below threshold / chi2 below threshold = 0.358294930876
# -> decided 2sigma


#first last strategy 2 sigma window (13h)
