ghostr_list_wsm_noUT = [0.2851832182687201, 0.2851832182687201, 0.2851832182687201, 0.2851832182687201, 0.2851832182687201, 0.2851832182687201, 0.28533475026567484, 0.28495481127060074, 0.2851063829787234, 0.2851063829787234, 0.28449653702717104, 0.2828066416711302, 0.2838709677419355, 0.2833964305029746, 0.2821486706456864, 0.28063457330415753, 0.28123280132085854, 0.28006681514476617, 0.27984234234234234, 0.2796561604584527]
err_eff_list_wsm_noUT =  [0.007836930616094638, 0.007836930616094638, 0.007836930616094638, 0.007836930616094638, 0.007836930616094638, 0.007836930616094638, 0.007859412851502993, 0.007859412851502993, 0.007881793366148764, 0.007881793366148764, 0.007904073024104116, 0.007992199901107281, 0.008142726815999661, 0.008288769734025895, 0.00832970587716037, 0.008490081358943592, 0.00866434156845255, 0.008905279333069794, 0.00915154712684226, 0.009513359028229725]
err_ghostr_list_wsm_noUT =  [0.010404810927339237, 0.010404810927339237, 0.010404810927339237, 0.010404810927339237, 0.010404810927339237, 0.010404810927339237, 0.010409236031989082, 0.0104078336853789, 0.010412266021572645, 0.010412266021572645, 0.010413871774284045, 0.010422952842401018, 0.010454413108779863, 0.010480167308029874, 0.010483193233370328, 0.010508900301262588, 0.010547502757027882, 0.010595556129240248, 0.010652438227394402, 0.010744455286948307]
belowthr_list_wsm_noUT = [0.0010740460850374913, 0.0022248346235987032, 0.0038020977616928485, 0.005653394685657633, 0.008799886681539715, 0.014013231053395405, 0.019386422976501304, 0.027931697387764333, 0.03651949853822903, 0.04745598449361977, 0.06569080867495847, 0.08514619883040936, 0.11237873496313543, 0.13995903637959622, 0.17296511627906977, 0.20792951541850221, 0.2464813511611541, 0.2889494652967079, 0.3288135593220339, 0.3808705612829324]




fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13,5))
fig.suptitle('Efficiency and ghost rate with and without UT station')

axs[0].errorbar(perc_list_noUT,eff_list_wsm_noUT,yerr=err_eff_list_wsm_noUT,fmt='o',label='without UT: correct matches / long tracks')
axs[0].errorbar(perc_list_UT,eff_list_wsm_UT,yerr=err_eff_list_wsm_UT,fmt='o',label='with UT: correct matches / long and downstream tracks')
axs[0].set_xlabel('chi2 percentage threshold')
axs[0].set_ylabel('Efficiency')
axs[0].legend(loc='best')
#axs[0].set_title('Efficiency')

axs[1].errorbar(perc_list_noUT,ghostr_list_wsm_noUT,yerr=err_ghostr_list_wsm_noUT,fmt='o',label='without UT: wrong matches / found matches')
axs[1].errorbar(perc_list_UT,ghostr_list_wsm_UT,yerr=err_ghostr_list_wsm_UT,fmt='o',label='with UT: wrong matches / found matches')
axs[1].set_xlabel('chi2 percentage threshold')
axs[1].set_ylabel('Ghost rate')
axs[1].legend(loc='best')
#axs[1].set_title('Ghost rate')

plt.show()



fig.suptitle('Efficiency and ghost rate with and without UT station')

plt.errorbar(eff_list_wsm_noUT,ghostr_list_wsm_noUT,xerr=err_eff_list_wsm_noUT, yerr=err_ghostr_list_wsm_noUT,fmt='o',label='without UT')
plt.errorbar(eff_list_wsm_UT,ghostr_list_wsm_UT,xerr=err_eff_list_wsm_UT,yerr=err_ghostr_list_wsm_UT,fmt='o',label='with UT')
plt.ylabel('Ghost rate')
plt.xlabel('Efficiency')
plt.ylim(0.16,0.30)
plt.xlim(0.83,0.93)

for i, txt in enumerate(perc_list_noUT):
    plt.annotate(txt, (eff_list_wsm_noUT[i], ghostr_list_wsm_noUT[i]))
    plt.annotate(txt, (eff_list_wsm_UT[i], ghostr_list_wsm_UT[i]))
plt.legend(loc='best')


plt.show()

# %%
#sigmas of the fit

perc_list_UT = range(99,60,-2)
perc_list_noUT = range(99,60,-2)

#with UT
eff_list_wsm_UT =  [0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9053333333333333, 0.9046666666666666, 0.904, 0.9, 0.896, 0.8926666666666667, 0.8893333333333333, 0.8806666666666667, 0.8713333333333333]
ghostr_list_wsm_UT =  [0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19929245283018868, 0.19834710743801653, 0.19787359716479622, 0.19751626256652868, 0.19715808170515098, 0.19642857142857142, 0.19569120287253142, 0.19434416365824309, 0.19347037484885127, 0.19204892966360856, 0.191713048855906]
err_eff_list_wsm_UT =  [0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007558875087775469, 0.007582650762931959, 0.007606313167363015, 0.007745966692414833, 0.007881793366148764, 0.007992199901107281, 0.008100187469252612, 0.00837030022913909, 0.0086452898758247]
err_ghostr_list_wsm_UT =  [0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.00969994927636744, 0.009688340965028878, 0.00968248541184833, 0.009681613604149797, 0.009680716169563688, 0.009693038363246597, 0.009705297127570614, 0.009706105789502002, 0.009712916296846083, 0.009741808706174056, 0.009789344470094073]

#without UT
eff_list_wsm_noUT = [0.896, 0.896, 0.896, 0.896, 0.896, 0.896, 0.896, 0.896, 0.896, 0.8946666666666667, 0.8946666666666667, 0.894, 0.8926666666666667, 0.8893333333333333, 0.8853333333333333, 0.882, 0.878, 0.874, 0.862, 0.8473333333333334]
ghostr_list_wsm_noUT = [0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.2862453531598513, 0.28654970760233917, 0.28617021276595744, 0.2848, 0.2847222222222222, 0.28548473486877346, 0.2852529601722282, 0.2844780962682531, 0.2842391304347826, 0.28321487151448876, 0.28286189683860236, 0.2782509937535491]
err_eff_list_wsm_noUT =  [0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007881793366148764, 0.007926252675853921, 0.007926252675853921, 0.007948333158593694, 0.007992199901107281, 0.008100187469252612, 0.008226713488071335, 0.00832970587716037, 0.008450483220897292, 0.008568313719746727, 0.008905279333069794, 0.009286533460000222]
err_ghostr_list_wsm_noUT =   [0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01041642129953732, 0.01042527325915721, 0.01042390925186869, 0.010422768921932406, 0.010430259807669304, 0.010452617118218516, 0.010475346753426639, 0.010492220946252916, 0.010515186924997671, 0.010535269932821825, 0.010606955831472045, 0.010679029380056977]



fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13,5))
fig.suptitle('Efficiency and ghost rate with and without UT station')

axs[0].errorbar(perc_list_noUT,eff_list_wsm_noUT,yerr=err_eff_list_wsm_noUT,fmt='o',label='without UT: correct matches / long tracks')
axs[0].errorbar(perc_list_UT,eff_list_wsm_UT,yerr=err_eff_list_wsm_UT,fmt='o',label='with UT: correct matches / long and downstream tracks')
axs[0].set_xlabel('chi2 percentage threshold')
axs[0].set_ylabel('Efficiency')
axs[0].legend(loc='best')
#axs[0].set_title('Efficiency')

axs[1].errorbar(perc_list_noUT,ghostr_list_wsm_noUT,yerr=err_ghostr_list_wsm_noUT,fmt='o',label='without UT: wrong matches / found matches')
axs[1].errorbar(perc_list_UT,ghostr_list_wsm_UT,yerr=err_ghostr_list_wsm_UT,fmt='o',label='with UT: wrong matches / found matches')
axs[1].set_xlabel('chi2 percentage threshold')
axs[1].set_ylabel('Ghost rate')
axs[1].legend(loc='best')
#axs[1].set_title('Ghost rate')

plt.show()




fig.suptitle('Efficiency and ghost rate with and without UT station')

plt.errorbar(eff_list_wsm_noUT,ghostr_list_wsm_noUT,xerr=err_eff_list_wsm_noUT, yerr=err_ghostr_list_wsm_noUT,fmt='o',label='without UT')
plt.errorbar(eff_list_wsm_UT,ghostr_list_wsm_UT,xerr=err_eff_list_wsm_UT,yerr=err_ghostr_list_wsm_UT,fmt='o',label='with UT')
plt.ylabel('Ghost rate')
plt.xlabel('Efficiency')
plt.ylim(0.16,0.30)
plt.xlim(0.83,0.93)

for i, txt in enumerate(perc_list_noUT):
    plt.annotate(txt, (eff_list_wsm_noUT[i], ghostr_list_wsm_noUT[i]))
    plt.annotate(txt, (eff_list_wsm_UT[i], ghostr_list_wsm_UT[i]))
plt.legend(loc='best')


plt.show()
